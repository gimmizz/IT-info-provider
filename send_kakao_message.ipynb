# %%
import json
import requests

url = "https://kapi.kakao.com/v2/api/talk/memo/default/send"

# 사용자 토큰
headers = {
    "Authorization": "Bearer " + 'FM3yKcmsJ51I_ZVJxgrr18arlQGS_fuUv4DlFwopcSEAAAF3xa3VGQ'
}

template = {
    "object_type" : "list",
    "header_title" : "초밥 사진",
    "header_link" : {
        "web_url" : "https://www.naver.com",
        "mobile_web_url" : "https://www.naver.com"
    },
    "contents" : [
        {
            "title" : "1. 광어초밥",
            "description" : "광어는 맛있다",
            "image_url" : "https://search1.kakaocdn.net/argon/0x200_85_hr/8x5qcdbcQwi",
            "image_width" : 50, "image_height" : 50,
            "link" : {
                "web_url" : "www.naver.com",
                "mobile_web_url" : "www.naver.com"
            }
        },
        {
            "title" : "2. 참치초밥",
            "description" : "참치는 맛있다",
            "image_url" : "https://search2.kakaocdn.net/argon/0x200_85_hr/IjIToH1S7J1",
            "image_width" : 50, "image_height" : 50,
            "link" : {
                "web_url" : "www.naver.com",
                "mobile_web_url" : "www.naver.com"
            }
        }
        
    ],
    "buttons" : [
        {
            "title" : "웹으로 이동",
            "link" : {
                "web_url" : "https://developers.kakao.com/",
                "mobile_web_url" : "https://developers.kakao.com/"
            }
        }
    ]
    
}

data = {
    "template_object" : json.dumps(template)
}

response = requests.post(url, data=data, headers=headers)
print(response.status_code)
if response.json().get('result_code') == 0:
    print('메시지를 성공적으로 보냈습니다.')
else:
    print('메시지를 성공적으로 보내지 못했습니다. 오류메시지 : ' + str(response.json()))
# Out:
# 200
# 메시지를 성공적으로 보냈습니다.

# %%
import json
import requests

url = "https://kapi.kakao.com/v2/api/talk/memo/default/send"

# 사용자 토큰
headers = {
    "Authorization": "Bearer " + 'FM3yKcmsJ51I_ZVJxgrr18arlQGS_fuUv4DlFwopcSEAAAF3xa3VGQ'
}

template = {
    "object_type": "feed",
    "content": {
        "title": "React VR",
        "description": "2017년 12월 26일 스크랩 내역입니다.",
        "image_url": "http://k.kakaocdn.net/dn/rH8st/btqiKupNsef/8oxu7K0BSxSMnj9QKShisK/kakaolink40_original.png",
        "image_width": 800,
        "image_height": 800,
        "link": {
            "web_url": "http://blog.naver.com/gotodagate?Redirect=Log&logNo=221170892162",
            "mobile_web_url": "http://blog.naver.com/gotodagate?Redirect=Log&logNo=221170892162"
        }
    },
    "buttons": [
        {
        "title": "웹으로 이동",
        "link": {
            "web_url": "http://blog.naver.com/gotodagate?Redirect=Log&logNo=221170892162",
            "mobile_web_url": "http://blog.naver.com/gotodagate?Redirect=Log&logNo=221170892162"
        }},
        {
        "title": "두 번째",
        "link": {
            "web_url": "http://blog.naver.com/gotodagate?Redirect=Log&logNo=221170892162",
            "mobile_web_url": "http://blog.naver.com/gotodagate?Redirect=Log&logNo=221170892162"
        }        
        }
    
]
}

data = {
    "template_object" : json.dumps(template)
}

response = requests.post(url, data=data, headers=headers)
print(response.status_code)
if response.json().get('result_code') == 0:
    print('메시지를 성공적으로 보냈습니다.')
else:
    print('메시지를 성공적으로 보내지 못했습니다. 오류메시지 : ' + str(response.json()))
# Out:
# 200
# 메시지를 성공적으로 보냈습니다.
